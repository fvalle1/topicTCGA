# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import os,sys, gc
import matplotlib.pyplot as plt
from scipy.stats import entropy
sys.path.append("/content/drive/My Drive/phd")
sys.path.append("/content/drive/My Drive/phd/hsbm-occam")
from hsbmpy import get_max_available_L
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
algorithm = "topsbm"
directory='/content/drive/My Drive/phd/datasets/cancers/lung'
L = get_max_available_L(directory, algorithm)-1
os.chdir(directory)

# %%
label = 'cancer.type'

df_topics = pd.read_csv("%s/%s_level_%d_topic-dist.csv"%(algorithm,algorithm,L)).set_index('doc').drop('i_doc', axis=1)
df_words = pd.read_csv("%s/%s_level_%d_word-dist.csv"%(algorithm,algorithm,L), index_col=0)
df_words.index=[g[:15] for g in df_words.index]
df = pd.read_csv("mainTable.csv", index_col=0).reindex(index=df_words.index)
df = df.divide(df.sum(0),1).transpose().fillna(0)
df_files=pd.read_csv("files.dat", index_col=0)
df_topics.insert(0,'tissue', df_files.reindex(index=df_topics.index)[label])
df_topic_tissue = df_topics.groupby('tissue').mean()
df_files.replace("Discordant_LUSC","LUAD", inplace=True)
df_files.head()
# Out:
#                                                  cases.0.submitter_id  ... Subtype_Selected
# file_name                                                              ...
# 2d683c1f-3a48-4bb8-84f9-bad6347c008b.FPKM.txt.gz         TCGA-05-4249  ...           LUAD.5
# 780ab54f-9100-447b-ba9e-75480e7be3d9.FPKM.txt.gz         TCGA-05-4382  ...           LUAD.6
# f8332a4b-0365-4732-a6b8-a3998872e24c.FPKM.txt.gz         TCGA-05-4384  ...           LUAD.1
# 755f981f-f957-48ec-9779-cf9887e19ab0.FPKM.txt.gz         TCGA-05-4389  ...           LUAD.2
# d0d7fae1-355e-4ada-a469-b69d59c1edfe.FPKM.txt.gz         TCGA-05-4390  ...           LUAD.2
#
# [5 rows x 16 columns]

# %% [markdown]
# ## NN based predictor

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Convolution1D
from tensorflow.keras.losses import binary_crossentropy,mean_squared_error, categorical_crossentropy
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import plot_model,to_categorical
from tensorflow.keras.callbacks import Callback, CSVLogger, EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.python.framework.graph_util import convert_variables_to_constants
from tensorflow.python.client.device_lib import list_local_devices
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
import numpy as np
import os,sys, gc
list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16786936562873749751, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17928951809544487343
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17877213065920856225
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11150726272
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9933453681815736776
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
df_labels=df_files.copy()
df_labels=df_labels.reindex(index=df_topics.index)

uniq = len(df_labels[label].unique())

X_train = df_topics.drop('tissue',1)
X_train = X_train.subtract(X_train.mean(0),1).divide(0.5*(X_train.max(0)-X_train.min(0)),1).values.astype(float) #SGD transform
Y_train = to_categorical(np.unique(df_labels[label], return_inverse=True)[1])
inputs = X_train.shape[1]

Y_train = np.argmax(Y_train, axis=-1)
uniq = 1
activation_func = "sigmoid"
lr = 0.01
momentum = 0.95
l1 = 0.01
l2 = 0.0001
loss=binary_crossentropy

classes=np.unique(df_labels[df_labels.index.isin(df.index)][label], return_inverse=True)[0]

X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, random_state=42, train_size=0.8)

print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (326, 12) (326,) (82, 12) (82,)

# %%
K.clear_session()

os.system("rm -rf log.csv")
csv_logger = CSVLogger('log.csv', append=True, separator=',')
es = EarlyStopping(monitor='val_loss', min_delta=1e-3, mode='min', patience=25)

model=Sequential()
model.add(Dense(units=20, input_dim=inputs, use_bias=True, bias_initializer="ones", activation="relu", kernel_regularizer=l1_l2(l1=l1, l2=l2)))
model.add(Dense(units=uniq, activation=activation_func))
model.compile(loss=loss, optimizer=SGD(lr=lr, momentum=momentum), metrics=['accuracy', 'AUC'])
K.set_learning_phase(0)

print(model.summary())
plot_model(model, to_file=f"model_{label}.png", dpi=600, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                260
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 281
# Trainable params: 281
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
with tf.device("GPU"):
    model.fit(X_train, Y_train, epochs=1000, batch_size=50, verbose=1, validation_split=0.4, callbacks=[csv_logger, es], shuffle=True, use_multiprocessing=True, workers=-1)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 4/4 [==============================] - 0s 80ms/step - loss: 1.3499 - accuracy: 0.4359 - auc: 0.6502 - val_loss: 1.1876 - val_accuracy: 0.5191 - val_auc: 0.8452
# Epoch 2/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1454 - accuracy: 0.6410 - auc: 0.7276 - val_loss: 1.0971 - val_accuracy: 0.6183 - val_auc: 0.9378
# Epoch 3/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1052 - accuracy: 0.5846 - auc: 0.9262 - val_loss: 1.1523 - val_accuracy: 0.5725 - val_auc: 0.9280
# Epoch 4/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1099 - accuracy: 0.5795 - auc: 0.9425 - val_loss: 1.0796 - val_accuracy: 0.6183 - val_auc: 0.9291
# Epoch 5/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9969 - accuracy: 0.7128 - auc: 0.9396 - val_loss: 0.9320 - val_accuracy: 0.8473 - val_auc: 0.9294
# Epoch 6/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8889 - accuracy: 0.8923 - auc: 0.9436 - val_loss: 0.8720 - val_accuracy: 0.9237 - val_auc: 0.9294
# Epoch 7/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8705 - accuracy: 0.8923 - auc: 0.9503 - val_loss: 0.8551 - val_accuracy: 0.9160 - val_auc: 0.9288
# Epoch 8/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8517 - accuracy: 0.8564 - auc: 0.9506 - val_loss: 0.8127 - val_accuracy: 0.9313 - val_auc: 0.9280
# Epoch 9/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8022 - accuracy: 0.9026 - auc: 0.9459 - val_loss: 0.7740 - val_accuracy: 0.9160 - val_auc: 0.9280
# Epoch 10/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7540 - accuracy: 0.9128 - auc: 0.9486 - val_loss: 0.7740 - val_accuracy: 0.8931 - val_auc: 0.9279
# Epoch 11/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7405 - accuracy: 0.9231 - auc: 0.9492 - val_loss: 0.7825 - val_accuracy: 0.8931 - val_auc: 0.9275
# Epoch 12/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7330 - accuracy: 0.9128 - auc: 0.9480 - val_loss: 0.7714 - val_accuracy: 0.8931 - val_auc: 0.9283
# Epoch 13/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7136 - accuracy: 0.9179 - auc: 0.9489 - val_loss: 0.7390 - val_accuracy: 0.8931 - val_auc: 0.9301
# Epoch 14/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6896 - accuracy: 0.9282 - auc: 0.9496 - val_loss: 0.7056 - val_accuracy: 0.9084 - val_auc: 0.9299
# Epoch 15/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6688 - accuracy: 0.9282 - auc: 0.9525 - val_loss: 0.6793 - val_accuracy: 0.9237 - val_auc: 0.9324
# Epoch 16/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6568 - accuracy: 0.9231 - auc: 0.9510 - val_loss: 0.6582 - val_accuracy: 0.9237 - val_auc: 0.9343
# Epoch 17/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6478 - accuracy: 0.9077 - auc: 0.9516 - val_loss: 0.6396 - val_accuracy: 0.9237 - val_auc: 0.9350
# Epoch 18/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6326 - accuracy: 0.9128 - auc: 0.9531 - val_loss: 0.6257 - val_accuracy: 0.9237 - val_auc: 0.9363
# Epoch 19/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6145 - accuracy: 0.9231 - auc: 0.9542 - val_loss: 0.6133 - val_accuracy: 0.9237 - val_auc: 0.9387
# Epoch 20/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5980 - accuracy: 0.9385 - auc: 0.9563 - val_loss: 0.6029 - val_accuracy: 0.9160 - val_auc: 0.9422
# Epoch 21/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5834 - accuracy: 0.9333 - auc: 0.9572 - val_loss: 0.5933 - val_accuracy: 0.9160 - val_auc: 0.9448
# Epoch 22/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5708 - accuracy: 0.9333 - auc: 0.9596 - val_loss: 0.5818 - val_accuracy: 0.9008 - val_auc: 0.9472
# Epoch 23/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5580 - accuracy: 0.9333 - auc: 0.9616 - val_loss: 0.5654 - val_accuracy: 0.9008 - val_auc: 0.9513
# Epoch 24/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5441 - accuracy: 0.9333 - auc: 0.9640 - val_loss: 0.5490 - val_accuracy: 0.9160 - val_auc: 0.9538
# Epoch 25/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5321 - accuracy: 0.9333 - auc: 0.9635 - val_loss: 0.5304 - val_accuracy: 0.9160 - val_auc: 0.9596
# Epoch 26/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5197 - accuracy: 0.9385 - auc: 0.9646 - val_loss: 0.5136 - val_accuracy: 0.9160 - val_auc: 0.9642
# Epoch 27/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5112 - accuracy: 0.9385 - auc: 0.9626 - val_loss: 0.4972 - val_accuracy: 0.9160 - val_auc: 0.9660
# Epoch 28/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4990 - accuracy: 0.9385 - auc: 0.9657 - val_loss: 0.4860 - val_accuracy: 0.9160 - val_auc: 0.9687
# Epoch 29/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4876 - accuracy: 0.9385 - auc: 0.9669 - val_loss: 0.4761 - val_accuracy: 0.9160 - val_auc: 0.9695
# Epoch 30/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4771 - accuracy: 0.9385 - auc: 0.9668 - val_loss: 0.4677 - val_accuracy: 0.9160 - val_auc: 0.9717
# Epoch 31/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4674 - accuracy: 0.9385 - auc: 0.9666 - val_loss: 0.4617 - val_accuracy: 0.9160 - val_auc: 0.9731
# Epoch 32/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4584 - accuracy: 0.9333 - auc: 0.9672 - val_loss: 0.4538 - val_accuracy: 0.9160 - val_auc: 0.9743
# Epoch 33/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4501 - accuracy: 0.9333 - auc: 0.9673 - val_loss: 0.4464 - val_accuracy: 0.9160 - val_auc: 0.9748
# Epoch 34/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4420 - accuracy: 0.9333 - auc: 0.9680 - val_loss: 0.4360 - val_accuracy: 0.9160 - val_auc: 0.9757
# Epoch 35/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4335 - accuracy: 0.9333 - auc: 0.9680 - val_loss: 0.4261 - val_accuracy: 0.9160 - val_auc: 0.9755
# Epoch 36/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4261 - accuracy: 0.9385 - auc: 0.9679 - val_loss: 0.4166 - val_accuracy: 0.9160 - val_auc: 0.9748
# Epoch 37/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4193 - accuracy: 0.9385 - auc: 0.9675 - val_loss: 0.4078 - val_accuracy: 0.9237 - val_auc: 0.9746
# Epoch 38/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4118 - accuracy: 0.9385 - auc: 0.9678 - val_loss: 0.4014 - val_accuracy: 0.9160 - val_auc: 0.9739
# Epoch 39/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4045 - accuracy: 0.9385 - auc: 0.9681 - val_loss: 0.3956 - val_accuracy: 0.9160 - val_auc: 0.9753
# Epoch 40/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3976 - accuracy: 0.9385 - auc: 0.9681 - val_loss: 0.3918 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 41/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3911 - accuracy: 0.9333 - auc: 0.9683 - val_loss: 0.3862 - val_accuracy: 0.9160 - val_auc: 0.9746
# Epoch 42/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3849 - accuracy: 0.9385 - auc: 0.9680 - val_loss: 0.3812 - val_accuracy: 0.9160 - val_auc: 0.9756
# Epoch 43/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3786 - accuracy: 0.9385 - auc: 0.9680 - val_loss: 0.3738 - val_accuracy: 0.9160 - val_auc: 0.9749
# Epoch 44/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3726 - accuracy: 0.9385 - auc: 0.9678 - val_loss: 0.3669 - val_accuracy: 0.9160 - val_auc: 0.9748
# Epoch 45/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3680 - accuracy: 0.9385 - auc: 0.9681 - val_loss: 0.3603 - val_accuracy: 0.9160 - val_auc: 0.9758
# Epoch 46/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3641 - accuracy: 0.9385 - auc: 0.9682 - val_loss: 0.3559 - val_accuracy: 0.9160 - val_auc: 0.9759
# Epoch 47/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3600 - accuracy: 0.9385 - auc: 0.9686 - val_loss: 0.3509 - val_accuracy: 0.9160 - val_auc: 0.9762
# Epoch 48/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3559 - accuracy: 0.9385 - auc: 0.9687 - val_loss: 0.3468 - val_accuracy: 0.9160 - val_auc: 0.9758
# Epoch 49/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3521 - accuracy: 0.9385 - auc: 0.9688 - val_loss: 0.3445 - val_accuracy: 0.9160 - val_auc: 0.9758
# Epoch 50/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3488 - accuracy: 0.9385 - auc: 0.9685 - val_loss: 0.3428 - val_accuracy: 0.9160 - val_auc: 0.9772
# Epoch 51/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3456 - accuracy: 0.9385 - auc: 0.9690 - val_loss: 0.3400 - val_accuracy: 0.9160 - val_auc: 0.9775
# Epoch 52/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3427 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.3379 - val_accuracy: 0.9160 - val_auc: 0.9764
# Epoch 53/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3404 - accuracy: 0.9385 - auc: 0.9686 - val_loss: 0.3334 - val_accuracy: 0.9160 - val_auc: 0.9761
# Epoch 54/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3373 - accuracy: 0.9385 - auc: 0.9684 - val_loss: 0.3310 - val_accuracy: 0.9160 - val_auc: 0.9757
# Epoch 55/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3347 - accuracy: 0.9385 - auc: 0.9682 - val_loss: 0.3292 - val_accuracy: 0.9160 - val_auc: 0.9748
# Epoch 56/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3323 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.3269 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 57/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3301 - accuracy: 0.9385 - auc: 0.9684 - val_loss: 0.3241 - val_accuracy: 0.9160 - val_auc: 0.9749
# Epoch 58/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3274 - accuracy: 0.9385 - auc: 0.9684 - val_loss: 0.3224 - val_accuracy: 0.9160 - val_auc: 0.9753
# Epoch 59/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3250 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.3213 - val_accuracy: 0.9160 - val_auc: 0.9745
# Epoch 60/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3240 - accuracy: 0.9385 - auc: 0.9676 - val_loss: 0.3224 - val_accuracy: 0.9160 - val_auc: 0.9753
# Epoch 61/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3214 - accuracy: 0.9385 - auc: 0.9685 - val_loss: 0.3183 - val_accuracy: 0.9160 - val_auc: 0.9756
# Epoch 62/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3195 - accuracy: 0.9385 - auc: 0.9682 - val_loss: 0.3137 - val_accuracy: 0.9160 - val_auc: 0.9755
# Epoch 63/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3174 - accuracy: 0.9385 - auc: 0.9688 - val_loss: 0.3108 - val_accuracy: 0.9160 - val_auc: 0.9755
# Epoch 64/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3156 - accuracy: 0.9385 - auc: 0.9684 - val_loss: 0.3093 - val_accuracy: 0.9160 - val_auc: 0.9752
# Epoch 65/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3135 - accuracy: 0.9385 - auc: 0.9687 - val_loss: 0.3076 - val_accuracy: 0.9160 - val_auc: 0.9756
# Epoch 66/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3125 - accuracy: 0.9385 - auc: 0.9682 - val_loss: 0.3085 - val_accuracy: 0.9160 - val_auc: 0.9756
# Epoch 67/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3105 - accuracy: 0.9385 - auc: 0.9676 - val_loss: 0.3082 - val_accuracy: 0.9160 - val_auc: 0.9763
# Epoch 68/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3087 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.3060 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 69/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3074 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.3019 - val_accuracy: 0.9160 - val_auc: 0.9762
# Epoch 70/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3057 - accuracy: 0.9436 - auc: 0.9684 - val_loss: 0.2993 - val_accuracy: 0.9160 - val_auc: 0.9762
# Epoch 71/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3046 - accuracy: 0.9436 - auc: 0.9687 - val_loss: 0.2989 - val_accuracy: 0.9160 - val_auc: 0.9761
# Epoch 72/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3033 - accuracy: 0.9385 - auc: 0.9681 - val_loss: 0.2984 - val_accuracy: 0.9160 - val_auc: 0.9753
# Epoch 73/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3021 - accuracy: 0.9385 - auc: 0.9685 - val_loss: 0.2978 - val_accuracy: 0.9160 - val_auc: 0.9759
# Epoch 74/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3011 - accuracy: 0.9385 - auc: 0.9685 - val_loss: 0.2973 - val_accuracy: 0.9160 - val_auc: 0.9761
# Epoch 75/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3016 - accuracy: 0.9385 - auc: 0.9669 - val_loss: 0.2993 - val_accuracy: 0.9160 - val_auc: 0.9734
# Epoch 76/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2994 - accuracy: 0.9385 - auc: 0.9675 - val_loss: 0.2961 - val_accuracy: 0.9160 - val_auc: 0.9739
# Epoch 77/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2982 - accuracy: 0.9385 - auc: 0.9684 - val_loss: 0.2940 - val_accuracy: 0.9160 - val_auc: 0.9737
# Epoch 78/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2972 - accuracy: 0.9385 - auc: 0.9682 - val_loss: 0.2936 - val_accuracy: 0.9160 - val_auc: 0.9736
# Epoch 79/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2967 - accuracy: 0.9385 - auc: 0.9678 - val_loss: 0.2932 - val_accuracy: 0.9160 - val_auc: 0.9727
# Epoch 80/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2957 - accuracy: 0.9385 - auc: 0.9681 - val_loss: 0.2927 - val_accuracy: 0.9160 - val_auc: 0.9729
# Epoch 81/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2950 - accuracy: 0.9385 - auc: 0.9680 - val_loss: 0.2914 - val_accuracy: 0.9160 - val_auc: 0.9730
# Epoch 82/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2939 - accuracy: 0.9385 - auc: 0.9682 - val_loss: 0.2902 - val_accuracy: 0.9160 - val_auc: 0.9738
# Epoch 83/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2936 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.2918 - val_accuracy: 0.9160 - val_auc: 0.9745
# Epoch 84/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2925 - accuracy: 0.9385 - auc: 0.9677 - val_loss: 0.2916 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 85/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2917 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.2893 - val_accuracy: 0.9160 - val_auc: 0.9727
# Epoch 86/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2912 - accuracy: 0.9385 - auc: 0.9679 - val_loss: 0.2876 - val_accuracy: 0.9160 - val_auc: 0.9738
# Epoch 87/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2903 - accuracy: 0.9385 - auc: 0.9684 - val_loss: 0.2865 - val_accuracy: 0.9160 - val_auc: 0.9745
# Epoch 88/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2893 - accuracy: 0.9385 - auc: 0.9687 - val_loss: 0.2867 - val_accuracy: 0.9160 - val_auc: 0.9727
# Epoch 89/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2886 - accuracy: 0.9333 - auc: 0.9687 - val_loss: 0.2857 - val_accuracy: 0.9160 - val_auc: 0.9738
# Epoch 90/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2883 - accuracy: 0.9333 - auc: 0.9683 - val_loss: 0.2862 - val_accuracy: 0.9160 - val_auc: 0.9727
# Epoch 91/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2872 - accuracy: 0.9385 - auc: 0.9690 - val_loss: 0.2857 - val_accuracy: 0.9160 - val_auc: 0.9733
# Epoch 92/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2866 - accuracy: 0.9385 - auc: 0.9680 - val_loss: 0.2851 - val_accuracy: 0.9160 - val_auc: 0.9739
# Epoch 93/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2860 - accuracy: 0.9385 - auc: 0.9683 - val_loss: 0.2849 - val_accuracy: 0.9160 - val_auc: 0.9745
# Epoch 94/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2853 - accuracy: 0.9385 - auc: 0.9685 - val_loss: 0.2829 - val_accuracy: 0.9160 - val_auc: 0.9745
# Epoch 95/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2844 - accuracy: 0.9385 - auc: 0.9695 - val_loss: 0.2810 - val_accuracy: 0.9160 - val_auc: 0.9744
# Epoch 96/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2840 - accuracy: 0.9385 - auc: 0.9692 - val_loss: 0.2787 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 97/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2836 - accuracy: 0.9385 - auc: 0.9692 - val_loss: 0.2774 - val_accuracy: 0.9160 - val_auc: 0.9752
# Epoch 98/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2826 - accuracy: 0.9385 - auc: 0.9698 - val_loss: 0.2784 - val_accuracy: 0.9160 - val_auc: 0.9755
# Epoch 99/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2822 - accuracy: 0.9436 - auc: 0.9691 - val_loss: 0.2809 - val_accuracy: 0.9160 - val_auc: 0.9746
# Epoch 100/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2816 - accuracy: 0.9385 - auc: 0.9690 - val_loss: 0.2825 - val_accuracy: 0.9160 - val_auc: 0.9748
# Epoch 101/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2812 - accuracy: 0.9385 - auc: 0.9693 - val_loss: 0.2822 - val_accuracy: 0.9160 - val_auc: 0.9744
# Epoch 102/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2802 - accuracy: 0.9385 - auc: 0.9693 - val_loss: 0.2796 - val_accuracy: 0.9160 - val_auc: 0.9756
# Epoch 103/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2808 - accuracy: 0.9333 - auc: 0.9686 - val_loss: 0.2739 - val_accuracy: 0.9160 - val_auc: 0.9757
# Epoch 104/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2791 - accuracy: 0.9385 - auc: 0.9696 - val_loss: 0.2736 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 105/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2785 - accuracy: 0.9385 - auc: 0.9688 - val_loss: 0.2736 - val_accuracy: 0.9160 - val_auc: 0.9748
# Epoch 106/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2778 - accuracy: 0.9385 - auc: 0.9692 - val_loss: 0.2730 - val_accuracy: 0.9160 - val_auc: 0.9756
# Epoch 107/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2773 - accuracy: 0.9385 - auc: 0.9699 - val_loss: 0.2738 - val_accuracy: 0.9160 - val_auc: 0.9759
# Epoch 108/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2769 - accuracy: 0.9333 - auc: 0.9695 - val_loss: 0.2754 - val_accuracy: 0.9160 - val_auc: 0.9756
# Epoch 109/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2762 - accuracy: 0.9385 - auc: 0.9692 - val_loss: 0.2752 - val_accuracy: 0.9160 - val_auc: 0.9765
# Epoch 110/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2757 - accuracy: 0.9385 - auc: 0.9693 - val_loss: 0.2739 - val_accuracy: 0.9160 - val_auc: 0.9765
# Epoch 111/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2751 - accuracy: 0.9333 - auc: 0.9698 - val_loss: 0.2723 - val_accuracy: 0.9160 - val_auc: 0.9761
# Epoch 112/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2746 - accuracy: 0.9385 - auc: 0.9697 - val_loss: 0.2717 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 113/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2743 - accuracy: 0.9385 - auc: 0.9696 - val_loss: 0.2706 - val_accuracy: 0.9160 - val_auc: 0.9751
# Epoch 114/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2746 - accuracy: 0.9385 - auc: 0.9692 - val_loss: 0.2681 - val_accuracy: 0.9237 - val_auc: 0.9755
# Epoch 115/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2736 - accuracy: 0.9385 - auc: 0.9698 - val_loss: 0.2687 - val_accuracy: 0.9160 - val_auc: 0.9766
# Epoch 116/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2727 - accuracy: 0.9385 - auc: 0.9703 - val_loss: 0.2712 - val_accuracy: 0.9160 - val_auc: 0.9777
# Epoch 117/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2726 - accuracy: 0.9385 - auc: 0.9702 - val_loss: 0.2736 - val_accuracy: 0.9160 - val_auc: 0.9765
# Epoch 118/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2722 - accuracy: 0.9436 - auc: 0.9701 - val_loss: 0.2736 - val_accuracy: 0.9160 - val_auc: 0.9768
# Epoch 119/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2715 - accuracy: 0.9385 - auc: 0.9704 - val_loss: 0.2693 - val_accuracy: 0.9160 - val_auc: 0.9772
# Epoch 120/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2722 - accuracy: 0.9385 - auc: 0.9702 - val_loss: 0.2645 - val_accuracy: 0.9313 - val_auc: 0.9776
# Epoch 121/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2707 - accuracy: 0.9333 - auc: 0.9703 - val_loss: 0.2649 - val_accuracy: 0.9313 - val_auc: 0.9769
# Epoch 122/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2701 - accuracy: 0.9333 - auc: 0.9703 - val_loss: 0.2655 - val_accuracy: 0.9160 - val_auc: 0.9771
# Epoch 123/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2696 - accuracy: 0.9385 - auc: 0.9704 - val_loss: 0.2651 - val_accuracy: 0.9160 - val_auc: 0.9778
# Epoch 124/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2688 - accuracy: 0.9385 - auc: 0.9709 - val_loss: 0.2661 - val_accuracy: 0.9160 - val_auc: 0.9781
# Epoch 125/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2690 - accuracy: 0.9436 - auc: 0.9705 - val_loss: 0.2693 - val_accuracy: 0.9160 - val_auc: 0.9776
# Epoch 126/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2686 - accuracy: 0.9385 - auc: 0.9708 - val_loss: 0.2675 - val_accuracy: 0.9160 - val_auc: 0.9772
# Epoch 127/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2677 - accuracy: 0.9436 - auc: 0.9709 - val_loss: 0.2668 - val_accuracy: 0.9160 - val_auc: 0.9787
# Epoch 128/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2676 - accuracy: 0.9385 - auc: 0.9712 - val_loss: 0.2641 - val_accuracy: 0.9160 - val_auc: 0.9800
# Epoch 129/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2670 - accuracy: 0.9385 - auc: 0.9713 - val_loss: 0.2623 - val_accuracy: 0.9160 - val_auc: 0.9808
# Epoch 130/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2669 - accuracy: 0.9385 - auc: 0.9714 - val_loss: 0.2641 - val_accuracy: 0.9160 - val_auc: 0.9808
# Epoch 131/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2663 - accuracy: 0.9385 - auc: 0.9718 - val_loss: 0.2638 - val_accuracy: 0.9160 - val_auc: 0.9809
# Epoch 132/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2656 - accuracy: 0.9385 - auc: 0.9716 - val_loss: 0.2616 - val_accuracy: 0.9160 - val_auc: 0.9788
# Epoch 133/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2663 - accuracy: 0.9333 - auc: 0.9714 - val_loss: 0.2586 - val_accuracy: 0.9313 - val_auc: 0.9806
# Epoch 134/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2654 - accuracy: 0.9333 - auc: 0.9709 - val_loss: 0.2609 - val_accuracy: 0.9160 - val_auc: 0.9790
# Epoch 135/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2644 - accuracy: 0.9385 - auc: 0.9714 - val_loss: 0.2603 - val_accuracy: 0.9160 - val_auc: 0.9809
# Epoch 136/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2639 - accuracy: 0.9385 - auc: 0.9723 - val_loss: 0.2608 - val_accuracy: 0.9160 - val_auc: 0.9802
# Epoch 137/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2639 - accuracy: 0.9385 - auc: 0.9718 - val_loss: 0.2599 - val_accuracy: 0.9160 - val_auc: 0.9812
# Epoch 138/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2638 - accuracy: 0.9385 - auc: 0.9710 - val_loss: 0.2627 - val_accuracy: 0.9160 - val_auc: 0.9808
# Epoch 139/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2632 - accuracy: 0.9385 - auc: 0.9720 - val_loss: 0.2613 - val_accuracy: 0.9160 - val_auc: 0.9808
# Epoch 140/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2627 - accuracy: 0.9385 - auc: 0.9720 - val_loss: 0.2601 - val_accuracy: 0.9160 - val_auc: 0.9809
# Epoch 141/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2622 - accuracy: 0.9385 - auc: 0.9721 - val_loss: 0.2584 - val_accuracy: 0.9160 - val_auc: 0.9802
# Epoch 142/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2618 - accuracy: 0.9385 - auc: 0.9719 - val_loss: 0.2579 - val_accuracy: 0.9160 - val_auc: 0.9806
# Epoch 143/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2617 - accuracy: 0.9385 - auc: 0.9723 - val_loss: 0.2558 - val_accuracy: 0.9313 - val_auc: 0.9806
# Epoch 144/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2612 - accuracy: 0.9333 - auc: 0.9725 - val_loss: 0.2556 - val_accuracy: 0.9313 - val_auc: 0.9806
# Epoch 145/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2609 - accuracy: 0.9333 - auc: 0.9730 - val_loss: 0.2557 - val_accuracy: 0.9237 - val_auc: 0.9804
# Epoch 146/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2607 - accuracy: 0.9333 - auc: 0.9722 - val_loss: 0.2565 - val_accuracy: 0.9160 - val_auc: 0.9800
# Epoch 147/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2602 - accuracy: 0.9385 - auc: 0.9725 - val_loss: 0.2576 - val_accuracy: 0.9160 - val_auc: 0.9808
# Epoch 148/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2602 - accuracy: 0.9385 - auc: 0.9725 - val_loss: 0.2560 - val_accuracy: 0.9160 - val_auc: 0.9814
# Epoch 149/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2595 - accuracy: 0.9385 - auc: 0.9731 - val_loss: 0.2559 - val_accuracy: 0.9160 - val_auc: 0.9814
# Epoch 150/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2597 - accuracy: 0.9385 - auc: 0.9725 - val_loss: 0.2555 - val_accuracy: 0.9160 - val_auc: 0.9810
# Epoch 151/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2588 - accuracy: 0.9385 - auc: 0.9730 - val_loss: 0.2547 - val_accuracy: 0.9160 - val_auc: 0.9807
# Epoch 152/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2588 - accuracy: 0.9385 - auc: 0.9729 - val_loss: 0.2538 - val_accuracy: 0.9160 - val_auc: 0.9813
# Epoch 153/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2591 - accuracy: 0.9385 - auc: 0.9729 - val_loss: 0.2559 - val_accuracy: 0.9160 - val_auc: 0.9815
# Epoch 154/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2582 - accuracy: 0.9385 - auc: 0.9736 - val_loss: 0.2557 - val_accuracy: 0.9160 - val_auc: 0.9809
# Epoch 155/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2578 - accuracy: 0.9385 - auc: 0.9736 - val_loss: 0.2533 - val_accuracy: 0.9160 - val_auc: 0.9809
# Epoch 156/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2573 - accuracy: 0.9333 - auc: 0.9732 - val_loss: 0.2514 - val_accuracy: 0.9313 - val_auc: 0.9810
# Epoch 157/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2584 - accuracy: 0.9333 - auc: 0.9731 - val_loss: 0.2480 - val_accuracy: 0.9313 - val_auc: 0.9814
# Epoch 158/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2575 - accuracy: 0.9333 - auc: 0.9735 - val_loss: 0.2493 - val_accuracy: 0.9313 - val_auc: 0.9813
# Epoch 159/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2589 - accuracy: 0.9333 - auc: 0.9717 - val_loss: 0.2548 - val_accuracy: 0.9160 - val_auc: 0.9809
# Epoch 160/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2565 - accuracy: 0.9385 - auc: 0.9731 - val_loss: 0.2529 - val_accuracy: 0.9160 - val_auc: 0.9813
# Epoch 161/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2560 - accuracy: 0.9385 - auc: 0.9733 - val_loss: 0.2523 - val_accuracy: 0.9160 - val_auc: 0.9816
# Epoch 162/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2559 - accuracy: 0.9333 - auc: 0.9733 - val_loss: 0.2513 - val_accuracy: 0.9160 - val_auc: 0.9820
# Epoch 163/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2555 - accuracy: 0.9333 - auc: 0.9739 - val_loss: 0.2518 - val_accuracy: 0.9160 - val_auc: 0.9810
# Epoch 164/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2555 - accuracy: 0.9333 - auc: 0.9734 - val_loss: 0.2497 - val_accuracy: 0.9313 - val_auc: 0.9821
# Epoch 165/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2553 - accuracy: 0.9333 - auc: 0.9737 - val_loss: 0.2485 - val_accuracy: 0.9313 - val_auc: 0.9817
# Epoch 166/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2556 - accuracy: 0.9333 - auc: 0.9738 - val_loss: 0.2478 - val_accuracy: 0.9313 - val_auc: 0.9826
# Epoch 167/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2543 - accuracy: 0.9333 - auc: 0.9742 - val_loss: 0.2508 - val_accuracy: 0.9160 - val_auc: 0.9822
# Epoch 168/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2539 - accuracy: 0.9436 - auc: 0.9743 - val_loss: 0.2527 - val_accuracy: 0.9160 - val_auc: 0.9816
# Epoch 169/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2541 - accuracy: 0.9436 - auc: 0.9744 - val_loss: 0.2545 - val_accuracy: 0.9160 - val_auc: 0.9809
# Epoch 170/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2539 - accuracy: 0.9436 - auc: 0.9740 - val_loss: 0.2528 - val_accuracy: 0.9160 - val_auc: 0.9817
# Epoch 171/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2535 - accuracy: 0.9436 - auc: 0.9742 - val_loss: 0.2493 - val_accuracy: 0.9237 - val_auc: 0.9815
# Epoch 172/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2534 - accuracy: 0.9333 - auc: 0.9742 - val_loss: 0.2463 - val_accuracy: 0.9313 - val_auc: 0.9817
# Epoch 173/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2527 - accuracy: 0.9333 - auc: 0.9740 - val_loss: 0.2463 - val_accuracy: 0.9313 - val_auc: 0.9819
# Epoch 174/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2524 - accuracy: 0.9333 - auc: 0.9741 - val_loss: 0.2464 - val_accuracy: 0.9313 - val_auc: 0.9819
# Epoch 175/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2522 - accuracy: 0.9333 - auc: 0.9738 - val_loss: 0.2474 - val_accuracy: 0.9313 - val_auc: 0.9815
# Epoch 176/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2525 - accuracy: 0.9333 - auc: 0.9740 - val_loss: 0.2486 - val_accuracy: 0.9237 - val_auc: 0.9817
# Epoch 177/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2518 - accuracy: 0.9385 - auc: 0.9740 - val_loss: 0.2490 - val_accuracy: 0.9160 - val_auc: 0.9827
# Epoch 178/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2516 - accuracy: 0.9385 - auc: 0.9747 - val_loss: 0.2482 - val_accuracy: 0.9160 - val_auc: 0.9827
# Epoch 179/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2512 - accuracy: 0.9333 - auc: 0.9748 - val_loss: 0.2464 - val_accuracy: 0.9313 - val_auc: 0.9829
# Epoch 180/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2510 - accuracy: 0.9333 - auc: 0.9744 - val_loss: 0.2455 - val_accuracy: 0.9313 - val_auc: 0.9829
# Epoch 181/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2509 - accuracy: 0.9333 - auc: 0.9743 - val_loss: 0.2452 - val_accuracy: 0.9313 - val_auc: 0.9828
# Epoch 182/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2506 - accuracy: 0.9333 - auc: 0.9746 - val_loss: 0.2441 - val_accuracy: 0.9313 - val_auc: 0.9828
# Epoch 183/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2503 - accuracy: 0.9333 - auc: 0.9747 - val_loss: 0.2448 - val_accuracy: 0.9313 - val_auc: 0.9826
# Epoch 184/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2499 - accuracy: 0.9333 - auc: 0.9749 - val_loss: 0.2454 - val_accuracy: 0.9237 - val_auc: 0.9834
# Epoch 185/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2498 - accuracy: 0.9333 - auc: 0.9752 - val_loss: 0.2455 - val_accuracy: 0.9237 - val_auc: 0.9838
# Epoch 186/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2497 - accuracy: 0.9333 - auc: 0.9752 - val_loss: 0.2463 - val_accuracy: 0.9237 - val_auc: 0.9827
# Epoch 187/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2495 - accuracy: 0.9385 - auc: 0.9748 - val_loss: 0.2450 - val_accuracy: 0.9237 - val_auc: 0.9836
# Epoch 188/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2497 - accuracy: 0.9333 - auc: 0.9752 - val_loss: 0.2434 - val_accuracy: 0.9313 - val_auc: 0.9841
# Epoch 189/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2498 - accuracy: 0.9333 - auc: 0.9746 - val_loss: 0.2463 - val_accuracy: 0.9237 - val_auc: 0.9835
# Epoch 190/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2490 - accuracy: 0.9385 - auc: 0.9748 - val_loss: 0.2450 - val_accuracy: 0.9237 - val_auc: 0.9847
# Epoch 191/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2491 - accuracy: 0.9385 - auc: 0.9752 - val_loss: 0.2453 - val_accuracy: 0.9160 - val_auc: 0.9842
# Epoch 192/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2488 - accuracy: 0.9385 - auc: 0.9750 - val_loss: 0.2448 - val_accuracy: 0.9237 - val_auc: 0.9841
# Epoch 193/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2486 - accuracy: 0.9333 - auc: 0.9751 - val_loss: 0.2401 - val_accuracy: 0.9313 - val_auc: 0.9839
# Epoch 194/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2481 - accuracy: 0.9333 - auc: 0.9750 - val_loss: 0.2392 - val_accuracy: 0.9313 - val_auc: 0.9835
# Epoch 195/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2482 - accuracy: 0.9333 - auc: 0.9751 - val_loss: 0.2387 - val_accuracy: 0.9313 - val_auc: 0.9840
# Epoch 196/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2481 - accuracy: 0.9333 - auc: 0.9752 - val_loss: 0.2394 - val_accuracy: 0.9313 - val_auc: 0.9844
# Epoch 197/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2476 - accuracy: 0.9333 - auc: 0.9753 - val_loss: 0.2434 - val_accuracy: 0.9237 - val_auc: 0.9841
# Epoch 198/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2471 - accuracy: 0.9385 - auc: 0.9752 - val_loss: 0.2455 - val_accuracy: 0.9160 - val_auc: 0.9847
# Epoch 199/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2480 - accuracy: 0.9436 - auc: 0.9758 - val_loss: 0.2486 - val_accuracy: 0.9160 - val_auc: 0.9840
# Epoch 200/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2470 - accuracy: 0.9436 - auc: 0.9752 - val_loss: 0.2446 - val_accuracy: 0.9160 - val_auc: 0.9842
# Epoch 201/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2467 - accuracy: 0.9385 - auc: 0.9761 - val_loss: 0.2402 - val_accuracy: 0.9313 - val_auc: 0.9846
# Epoch 202/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2471 - accuracy: 0.9333 - auc: 0.9748 - val_loss: 0.2363 - val_accuracy: 0.9313 - val_auc: 0.9845
# Epoch 203/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2470 - accuracy: 0.9333 - auc: 0.9754 - val_loss: 0.2368 - val_accuracy: 0.9313 - val_auc: 0.9844
# Epoch 204/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2462 - accuracy: 0.9333 - auc: 0.9759 - val_loss: 0.2381 - val_accuracy: 0.9313 - val_auc: 0.9838
# Epoch 205/1000
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2462 - accuracy: 0.9333 - auc: 0.9754 - val_loss: 0.2380 - val_accuracy: 0.9313 - val_auc: 0.9855
# Epoch 206/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2463 - accuracy: 0.9385 - auc: 0.9755 - val_loss: 0.2435 - val_accuracy: 0.9160 - val_auc: 0.9853
# Epoch 207/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2463 - accuracy: 0.9436 - auc: 0.9763 - val_loss: 0.2459 - val_accuracy: 0.9160 - val_auc: 0.9849
# Epoch 208/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2470 - accuracy: 0.9436 - auc: 0.9760 - val_loss: 0.2414 - val_accuracy: 0.9237 - val_auc: 0.9851
# Epoch 209/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2451 - accuracy: 0.9385 - auc: 0.9763 - val_loss: 0.2398 - val_accuracy: 0.9313 - val_auc: 0.9852
# Epoch 210/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2450 - accuracy: 0.9333 - auc: 0.9764 - val_loss: 0.2374 - val_accuracy: 0.9313 - val_auc: 0.9855
# Epoch 211/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2448 - accuracy: 0.9333 - auc: 0.9764 - val_loss: 0.2363 - val_accuracy: 0.9313 - val_auc: 0.9849
# Epoch 212/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2450 - accuracy: 0.9333 - auc: 0.9758 - val_loss: 0.2379 - val_accuracy: 0.9313 - val_auc: 0.9849
# Epoch 213/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2448 - accuracy: 0.9333 - auc: 0.9757 - val_loss: 0.2369 - val_accuracy: 0.9313 - val_auc: 0.9848
# Epoch 214/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2449 - accuracy: 0.9385 - auc: 0.9756 - val_loss: 0.2403 - val_accuracy: 0.9237 - val_auc: 0.9849
# Epoch 215/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2441 - accuracy: 0.9385 - auc: 0.9760 - val_loss: 0.2407 - val_accuracy: 0.9237 - val_auc: 0.9848
# Epoch 216/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2439 - accuracy: 0.9385 - auc: 0.9755 - val_loss: 0.2398 - val_accuracy: 0.9237 - val_auc: 0.9845
# Epoch 217/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2448 - accuracy: 0.9385 - auc: 0.9753 - val_loss: 0.2363 - val_accuracy: 0.9313 - val_auc: 0.9852
# Epoch 218/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2445 - accuracy: 0.9385 - auc: 0.9762 - val_loss: 0.2392 - val_accuracy: 0.9313 - val_auc: 0.9851
# Epoch 219/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2438 - accuracy: 0.9385 - auc: 0.9760 - val_loss: 0.2373 - val_accuracy: 0.9313 - val_auc: 0.9849
# Epoch 220/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2434 - accuracy: 0.9385 - auc: 0.9758 - val_loss: 0.2372 - val_accuracy: 0.9313 - val_auc: 0.9844
# Epoch 221/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2432 - accuracy: 0.9385 - auc: 0.9757 - val_loss: 0.2367 - val_accuracy: 0.9313 - val_auc: 0.9844
# Epoch 222/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2434 - accuracy: 0.9385 - auc: 0.9757 - val_loss: 0.2368 - val_accuracy: 0.9313 - val_auc: 0.9852
# Epoch 223/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2436 - accuracy: 0.9385 - auc: 0.9761 - val_loss: 0.2377 - val_accuracy: 0.9313 - val_auc: 0.9852
# Epoch 224/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2428 - accuracy: 0.9385 - auc: 0.9762 - val_loss: 0.2382 - val_accuracy: 0.9313 - val_auc: 0.9851
# Epoch 225/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2429 - accuracy: 0.9385 - auc: 0.9760 - val_loss: 0.2366 - val_accuracy: 0.9313 - val_auc: 0.9847
# Epoch 226/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2426 - accuracy: 0.9385 - auc: 0.9757 - val_loss: 0.2382 - val_accuracy: 0.9313 - val_auc: 0.9844
# Epoch 227/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2427 - accuracy: 0.9385 - auc: 0.9760 - val_loss: 0.2361 - val_accuracy: 0.9313 - val_auc: 0.9849

# %%
pd.read_csv("log.csv", sep=",")[['loss','val_loss']].plot()

# %%
model.evaluate(X_test, Y_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.9268 - auc: 0.9493
# [0.32368770241737366, 0.9268292784690857, 0.9492517709732056]

# %%
model.save(f"model_{label}.h5")
model = load_model(f"model_{label}.h5")

# %%
gc.collect()
# Out:
# 36

# %% [markdown]
# # evaluate on non used on topsbm training

# %%
classes = df_files[label].unique()
np.savetxt("classes.txt", classes, fmt="%s")
np.savetxt("X_test.txt", X_test)
np.savetxt("Y_test.txt", Y_test)
print(X_test.shape, Y_test.shape)
# Out:
# (82, 12) (82,)

# %%
model.evaluate(X_test, Y_test, verbose=2, workers=-1, use_multiprocessing=True)
# Out:
# 3/3 - 0s - loss: 0.3237 - accuracy: 0.9268 - auc: 0.9493
# [0.32368770241737366, 0.9268292784690857, 0.9492517709732056]

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
import seaborn as sns

# %%
y_pred_p = model.predict(X_test).ravel()
y_true = Y_test
y_pred = np.ones(y_pred_p.shape)
y_pred[y_pred_p<0.4]=0
results = confusion_matrix(y_true, y_pred, normalize="true")

# %%
cm = sns.clustermap(results, 
                    vmax=1,  
                    row_cluster=False, 
                    col_cluster=False, 
                    xticklabels=classes, 
                    yticklabels=classes, 
                    annot=False,
                    annot_kws={"fontsize":25})
ax = cm.ax_heatmap
fig = ax.get_figure()
ax.set_ylabel("real", fontsize=35, rotation=90)
ax.set_yticklabels(labels=classes, rotation=0)
ax.yaxis.tick_left()
ax.yaxis.set_label_position("left")

ax.set_xticklabels(labels=classes, rotation=45)
ax.set_xlabel("predicted",fontsize=35)
ax.tick_params(labelsize=35)

cax = cm.ax_cbar
cax.tick_params(labelsize=30)
cax.set_title("P()", fontsize=30)
plt.tight_layout()
cm.savefig(f"predict_{label}.pdf")

plt.show()

# %%
fig, ax= plt.subplots(figsize=(18,15))

ax.hist(y_pred_p[Y_test==0], histtype="step", lw=15, bins=10, density=True, label=classes[0])
ax.hist(y_pred_p[Y_test==1], histtype="step", lw=15, bins=10, density=True, label=classes[1])

ax.tick_params(labelsize=35)
ax.legend(fontsize=35, loc="upper left")
ax.set_title("", fontsize=35)

ax.set_xlim(-0.05,1.05)

ax.set_xlabel("Z", fontsize=35)
ax.set_ylabel("pdf", fontsize=35)

plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_true, y_pred_p)

# %%
fig, ax = plt.subplots(figsize=(18,15))

ax.plot(fpr,tpr, c="gray", lw=15)

ax.plot([0, 1], [0, 1], 'k--', lw=15)
ax.set_xlabel('False positive rate', fontsize=35)
ax.set_ylabel('True positive rate', fontsize=35)


for f, t, thr in zip(fpr[::100], tpr[::100], thresholds[::100]):
    ax.annotate(thr, (f, t), fontsize=25)

ax.annotate("Area Under Curve = %.4f"%roc_auc_score(y_true, y_pred_p), xy=(0.6, 0.5), fontsize=25)

ax.tick_params(labelsize=35)

plt.show()
fig.savefig(f"roc_{label}.pdf")

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score, auc

# %%
cv = KFold(n_splits=3)

param_grid = {"C":np.linspace(1,20,10)}
model = LogisticRegression(C=1., fit_intercept=True)

gs = GridSearchCV(model, param_grid, cv = cv, n_jobs=-1)

# %%
gs.fit(X_train, Y_train)
gs.best_params_
# Out:
# {'C': 11.555555555555555}

# %%
model = gs.best_estimator_

# %%
y_pred = model.predict(X_test)
y_pred_p = model.predict_proba(X_test).T[1]

# %%
accuracy_score(Y_test, y_pred)
# Out:
# 0.926829268292683

# %%
fpr, tpr, thresholds = roc_curve(np.abs(y_true-1), y_pred_p.T[0])
auc(fpr, tpr)
# Out:
# 0.9466493168510084
